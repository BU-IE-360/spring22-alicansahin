# %%
setwd("C:/Users/alica/OneDrive/Masaüstü/ali belgeler/BOUN/3.Sınıf/2.DÖNEM/IE 360/HW1")
#install.packages("ggplot2")
#install.packages("data.table")
#install.packages("corrplot")
library(ggplot2)
library(data.table)
#install.packages("https://cran.r-project.org/src/contrib/Archive/lubridate/lubridate_1.7.4.tar.gz",repos=NULL)
# Out:
# Registered S3 methods overwritten by 'tibble':
#   method     from
#   format.tbl pillar
#   print.tbl  pillar
# Warning message:
# "package 'data.table' was built under R version 3.6.3"

# %%
library(lubridate)
sold_house_data = read.csv("toplam_konut_satış.csv")
setDT(sold_house_data)
sold_house_data[,year_of_date:=year(ym(tarih))]
sold_house_data[,month_of_date:=month(ym(tarih))]
sold_house_data
yearly_sold = sold_house_data[,list(total = sum(toplam_satış)),list(year_of_date)]
yearly_sold
# Out:
# Warning message:
# "package 'lubridate' was built under R version 3.6.3"
# Attaching package: 'lubridate'
#
# The following objects are masked from 'package:data.table':
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# The following objects are masked from 'package:base':
#
#     date, intersect, setdiff, union
#     tarih   toplam_satış year_of_date month_of_date
# 1   2016-01 40077        2016          1
# 2   2016-02 47409        2016          2
# 3   2016-03 52374        2016          3
# 4   2016-04 46908        2016          4
# 5   2016-05 56043        2016          5
# 6   2016-06 49354        2016          6
# 7   2016-07 37829        2016          7
# 8   2016-08 53784        2016          8
# 9   2016-09 50972        2016          9
# 10  2016-10 61677        2016         10
# 11  2016-11 63467        2016         11
# 12  2016-12 71792        2016         12
# 13  2017-01 44235        2017          1
# 14  2017-02 45215        2017          2
# 15  2017-03 56376        2017          3
# 16  2017-04 51988        2017          4
# 17  2017-05 52976        2017          5
# 18  2017-06 45433        2017          6
# 19  2017-07 53949        2017          7
# 20  2017-08 56498        2017          8
# 21  2017-09 70019        2017          9
# 22  2017-10 56994        2017         10
# 23  2017-11 59354        2017         11
# 24  2017-12 66661        2017         12
# 25  2018-01 44363        2018          1
# 26  2018-02 43713        2018          2
# 27  2018-03 50701        2018          3
# 28  2018-04 47534        2018          4
# 29  2018-05 55502        2018          5
# 30  2018-06 57064        2018          6
# ... ...     ...          ...          ...
# 43  2019-07 38931        2019          7
# 44  2019-08 40634        2019          8
# 45  2019-09 51393        2019          9
# 46  2019-10 50181        2019         10
# 47  2019-11 48909        2019         11
# 48  2019-12 75480        2019         12
# 49  2020-01 36040        2020          1
# 50  2020-02 37303        2020          2
# 51  2020-03 34089        2020          3
# 52  2020-04 14848        2020          4
# 53  2020-05 16860        2020          5
# 54  2020-06 58632        2020          6
# 55  2020-07 67937        2020          7
# 56  2020-08 52123        2020          8
# 57  2020-09 41376        2020          9
# 58  2020-10 36976        2020         10
# 59  2020-11 36658        2020         11
# 60  2020-12 36898        2020         12
# 61  2021-01 22268        2021          1
# 62  2021-02 24737        2021          2
# 63  2021-03 33365        2021          3
# 64  2021-04 29212        2021          4
# 65  2021-05 18204        2021          5
# 66  2021-06 40092        2021          6
# 67  2021-07 32672        2021          7
# 68  2021-08 42639        2021          8
# 69  2021-09 43967        2021          9
# 70  2021-10 41914        2021         10
# 71  2021-11 55706        2021         11
# 72  2021-12 76747        2021         12
#   year_of_date total
# 1 2016         631686
# 2 2017         659698
# 3 2018         651572
# 4 2019         511682
# 5 2020         469740
# 6 2021         461523

# %%
ggplot(yearly_sold,aes(x=year_of_date,y= total)) + 
geom_line() + ylab("Total Sold House") + xlab("Years") + ggtitle("Total Sold House in Spesific Years")
# Out:
# plot without title

# %%
ggplot(sold_house_data,aes(x=factor(year_of_date),y=toplam_satış)) + geom_boxplot(aes(fill = factor(year_of_date)))+ labs(fill="Years")+
xlab("Years") + ylab("Total Sold House") + ggtitle("Boxplot of Total Sold House vs Years")
ggplot(sold_house_data,aes(x=month_of_date,y=toplam_satış)) +
geom_line() + facet_wrap(~year_of_date) + scale_x_discrete(limits = c(1:12))+xlab("Months") + ylab("Total Sold House")
# Out:
# Warning message:
# "Continuous limits supplied to discrete scale.
# Did you mean `limits = factor(...)` or `scale_*_continuous()`?"
# plot without title
# plot without title

# %%
konut_kredi_faiz = read.csv("konut_kredi_faiz.csv")
setDT(konut_kredi_faiz )
konut_kredi_faiz[,year_of_date := year(ym(tarih))]
konut_kredi_faiz[,month_of_date := month(ym(tarih))]
konut_kredi_faiz
# Out:
#     tarih   faiz_oran year_of_date month_of_date
# 1   2016-01 14.27     2016          1
# 2   2016-02 14.45     2016          2
# 3   2016-03 14.45     2016          3
# 4   2016-04 14.33     2016          4
# 5   2016-05 13.96     2016          5
# 6   2016-06 13.84     2016          6
# 7   2016-07 13.67     2016          7
# 8   2016-08 12.86     2016          8
# 9   2016-09 12.09     2016          9
# 10  2016-10 12.12     2016         10
# 11  2016-11 11.69     2016         11
# 12  2016-12 11.42     2016         12
# 13  2017-01 11.45     2017          1
# 14  2017-02 11.38     2017          2
# 15  2017-03 11.06     2017          3
# 16  2017-04 11.28     2017          4
# 17  2017-05 11.55     2017          5
# 18  2017-06 11.72     2017          6
# 19  2017-07 12.02     2017          7
# 20  2017-08 12.49     2017          8
# 21  2017-09 12.87     2017          9
# 22  2017-10 13.05     2017         10
# 23  2017-11 13.12     2017         11
# 24  2017-12 13.52     2017         12
# 25  2018-01 14.14     2018          1
# 26  2018-02 14.68     2018          2
# 27  2018-03 14.79     2018          3
# 28  2018-04 14.83     2018          4
# 29  2018-05 13.88     2018          5
# 30  2018-06 13.10     2018          6
# ... ...     ...       ...          ...
# 43  2019-07 21.06     2019          7
# 44  2019-08 14.15     2019          8
# 45  2019-09 12.98     2019          9
# 46  2019-10 13.12     2019         10
# 47  2019-11 12.96     2019         11
# 48  2019-12 12.69     2019         12
# 49  2020-01 11.88     2020          1
# 50  2020-02 11.43     2020          2
# 51  2020-03 11.40     2020          3
# 52  2020-04 11.72     2020          4
# 53  2020-05 11.23     2020          5
# 54  2020-06  9.30     2020          6
# 55  2020-07  9.11     2020          7
# 56  2020-08 11.09     2020          8
# 57  2020-09 14.16     2020          9
# 58  2020-10 15.07     2020         10
# 59  2020-11 15.68     2020         11
# 60  2020-12 18.19     2020         12
# 61  2021-01 18.39     2021          1
# 62  2021-02 17.99     2021          2
# 63  2021-03 17.74     2021          3
# 64  2021-04 18.13     2021          4
# 65  2021-05 17.84     2021          5
# 66  2021-06 17.90     2021          6
# 67  2021-07 17.93     2021          7
# 68  2021-08 17.86     2021          8
# 69  2021-09 17.90     2021          9
# 70  2021-10 17.82     2021         10
# 71  2021-11 17.10     2021         11
# 72  2021-12 17.31     2021         12

# %%
ggplot(konut_kredi_faiz, aes(x=factor(year_of_date),y = faiz_oran)) + geom_boxplot(aes(fill = factor(year_of_date)))+
labs(x="Years",y="Interest Rates",title="Boxplot of interest rates in years") +theme(legend.position = "none")
ggplot(konut_kredi_faiz,aes(month_of_date,faiz_oran,fill=factor(year_of_date))) + geom_bar(stat = 'identity') +labs(fill="Years") + facet_wrap(~year_of_date)+scale_x_discrete(limits = c(1:12))+ylab("Interest Rates") + xlab("Months")+
ggtitle("Monthly interest rates in different years")
# Out:
# Warning message:
# "Continuous limits supplied to discrete scale.
# Did you mean `limits = factor(...)` or `scale_*_continuous()`?"
# plot without title
# plot without title

# %%
gecinme_index = read.csv("gecinme_index.csv")
setDT(gecinme_index)
gecinme_index[,year_of_date := year(ym(tarih))]
gecinme_index[,month_of_date := month(ym(tarih))]
gecinme_index
# Out:
#     tarih   gecinme_index year_of_date month_of_date
# 1   2016-01 14062.4       2016          1
# 2   2016-02 14244.0       2016          2
# 3   2016-03 14281.5       2016          3
# 4   2016-04 14435.1       2016          4
# 5   2016-05 14419.6       2016          5
# 6   2016-06 14447.1       2016          6
# 7   2016-07 14574.1       2016          7
# 8   2016-08 14554.1       2016          8
# 9   2016-09 14637.8       2016          9
# 10  2016-10 14814.3       2016         10
# 11  2016-11 14901.9       2016         11
# 12  2016-12 15156.9       2016         12
# 13  2017-01 15407.0       2017          1
# 14  2017-02 15457.9       2017          2
# 15  2017-03 15566.3       2017          3
# 16  2017-04 15743.9       2017          4
# 17  2017-05 15793.1       2017          5
# 18  2017-06 15802.7       2017          6
# 19  2017-07 15833.5       2017          7
# 20  2017-08 15837.2       2017          8
# 21  2017-09 15984.5       2017          9
# 22  2017-10 16295.1       2017         10
# 23  2017-11 16489.5       2017         11
# 24  2017-12 16596.4       2017         12
# 25  2018-01 16740.7       2018          1
# 26  2018-02 16852.5       2018          2
# 27  2018-03 17070.3       2018          3
# 28  2018-04 17354.3       2018          4
# 29  2018-05 17499.7       2018          5
# 30  2018-06 17722.0       2018          6
# ... ...     ...           ...          ...
# 43  2019-07 20677.1       2019          7
# 44  2019-08 21199.4       2019          8
# 45  2019-09 21435.3       2019          9
# 46  2019-10 21816.8       2019         10
# 47  2019-11 21914.7       2019         11
# 48  2019-12 22149.3       2019         12
# 49  2020-01 22278.1       2020          1
# 50  2020-02 22530.4       2020          2
# 51  2020-03 22604.2       2020          3
# 52  2020-04 22838.6       2020          4
# 53  2020-05 23332.7       2020          5
# 54  2020-06 23348.3       2020          6
# 55  2020-07 23450.1       2020          7
# 56  2020-08 23589.1       2020          8
# 57  2020-09 23934.8       2020          9
# 58  2020-10 24521.4       2020         10
# 59  2020-11 24997.1       2020         11
# 60  2020-12 25337.7       2020         12
# 61  2021-01 25632.0       2021          1
# 62  2021-02 26012.0       2021          2
# 63  2021-03 26305.1       2021          3
# 64  2021-04 26570.7       2021          4
# 65  2021-05 27015.4       2021          5
# 66  2021-06 27113.1       2021          6
# 67  2021-07 27525.9       2021          7
# 68  2021-08 28044.3       2021          8
# 69  2021-09 28667.7       2021          9
# 70  2021-10 29611.7       2021         10
# 71  2021-11 31007.8       2021         11
# 72  2021-12 33998.8       2021         12

# %%
ggplot(gecinme_index,aes(month_of_date,gecinme_index,color=factor(year_of_date))) +
geom_point() + scale_x_discrete(limits = c(1:12)) + ylab("Cost of Living Index") + xlab("Months") + ggtitle("Cost of Living Index in Months")
# Out:
# Warning message:
# "Continuous limits supplied to discrete scale.
# Did you mean `limits = factor(...)` or `scale_*_continuous()`?"
# plot without title

# %%
ggplot(gecinme_index,aes(x=month_of_date,y=gecinme_index)) + geom_line(aes(color=factor(year_of_date))) + facet_wrap(~year_of_date) +
scale_x_discrete(limits = c(1:12)) + ylab("Cost of Living Index") + xlab("Months") + ggtitle("Monthly Index in Different Years")
# Out:
# Warning message:
# "Continuous limits supplied to discrete scale.
# Did you mean `limits = factor(...)` or `scale_*_continuous()`?"
# plot without title

# %%
house_search = read.csv("satılık_arama.csv")
setDT(house_search)

house_search[,year_of_date := year(ym(tarih))]
house_search[,month_of_date := month(ym(tarih))]
house_search
# Out:
#     tarih   arama year_of_date month_of_date
# 1   2016-01 27    2016          1
# 2   2016-02 31    2016          2
# 3   2016-03 33    2016          3
# 4   2016-04 31    2016          4
# 5   2016-05 32    2016          5
# 6   2016-06 28    2016          6
# 7   2016-07 32    2016          7
# 8   2016-08 39    2016          8
# 9   2016-09 35    2016          9
# 10  2016-10 35    2016         10
# 11  2016-11 34    2016         11
# 12  2016-12 30    2016         12
# 13  2017-01 34    2017          1
# 14  2017-02 41    2017          2
# 15  2017-03 38    2017          3
# 16  2017-04 34    2017          4
# 17  2017-05 32    2017          5
# 18  2017-06 34    2017          6
# 19  2017-07 41    2017          7
# 20  2017-08 37    2017          8
# 21  2017-09 35    2017          9
# 22  2017-10 33    2017         10
# 23  2017-11 32    2017         11
# 24  2017-12 32    2017         12
# 25  2018-01 33    2018          1
# 26  2018-02 35    2018          2
# 27  2018-03 34    2018          3
# 28  2018-04 32    2018          4
# 29  2018-05 34    2018          5
# 30  2018-06 32    2018          6
# ... ...     ...   ...          ...
# 43  2019-07  35   2019          7
# 44  2019-08  45   2019          8
# 45  2019-09  40   2019          9
# 46  2019-10  38   2019         10
# 47  2019-11  35   2019         11
# 48  2019-12  36   2019         12
# 49  2020-01  43   2020          1
# 50  2020-02  41   2020          2
# 51  2020-03  33   2020          3
# 52  2020-04  36   2020          4
# 53  2020-05  59   2020          5
# 54  2020-06 100   2020          6
# 55  2020-07  74   2020          7
# 56  2020-08  71   2020          8
# 57  2020-09  52   2020          9
# 58  2020-10  48   2020         10
# 59  2020-11  43   2020         11
# 60  2020-12  40   2020         12
# 61  2021-01  46   2021          1
# 62  2021-02  44   2021          2
# 63  2021-03  42   2021          3
# 64  2021-04  41   2021          4
# 65  2021-05  48   2021          5
# 66  2021-06  48   2021          6
# 67  2021-07  49   2021          7
# 68  2021-08  49   2021          8
# 69  2021-09  44   2021          9
# 70  2021-10  43   2021         10
# 71  2021-11  44   2021         11
# 72  2021-12  46   2021         12

# %%
ggplot(house_search,aes(x=month_of_date,y=arama)) +geom_line(aes(color=factor(year_of_date))) + facet_wrap(~year_of_date)+ylab("Search") +xlab("Months")+scale_x_discrete(limits = c(1:12))+
ggtitle("Search Volumes in Months")
# Out:
# Warning message:
# "Continuous limits supplied to discrete scale.
# Did you mean `limits = factor(...)` or `scale_*_continuous()`?"
# plot without title

# %%
ggplot(house_search,aes(month_of_date,arama,color=factor(year_of_date))) + geom_line() + scale_x_discrete(limits = c(1:12))+
ylab("Search") +xlab("Months") + ggtitle("Search Volumes in Months")
# Out:
# Warning message:
# "Continuous limits supplied to discrete scale.
# Did you mean `limits = factor(...)` or `scale_*_continuous()`?"
# plot without title

# %%
library(corrplot)
data_table_summary = data.table(date=sold_house_data$tarih,sold_house=sold_house_data$toplam_satış,interest_rate=konut_kredi_faiz$faiz_oran,cost_of_living_index = gecinme_index$gecinme_index,search_volume = house_search$arama)
data_table_summary[,month_of_date := as.factor(month(ym(date)))]
data_table_summary[,year_of_date := as.factor(month(ym(date)))]
data_table_summary
# Out:
#     date    sold_house interest_rate cost_of_living_index search_volume
# 1   2016-01 40077      14.27         14062.4              27
# 2   2016-02 47409      14.45         14244.0              31
# 3   2016-03 52374      14.45         14281.5              33
# 4   2016-04 46908      14.33         14435.1              31
# 5   2016-05 56043      13.96         14419.6              32
# 6   2016-06 49354      13.84         14447.1              28
# 7   2016-07 37829      13.67         14574.1              32
# 8   2016-08 53784      12.86         14554.1              39
# 9   2016-09 50972      12.09         14637.8              35
# 10  2016-10 61677      12.12         14814.3              35
# 11  2016-11 63467      11.69         14901.9              34
# 12  2016-12 71792      11.42         15156.9              30
# 13  2017-01 44235      11.45         15407.0              34
# 14  2017-02 45215      11.38         15457.9              41
# 15  2017-03 56376      11.06         15566.3              38
# 16  2017-04 51988      11.28         15743.9              34
# 17  2017-05 52976      11.55         15793.1              32
# 18  2017-06 45433      11.72         15802.7              34
# 19  2017-07 53949      12.02         15833.5              41
# 20  2017-08 56498      12.49         15837.2              37
# 21  2017-09 70019      12.87         15984.5              35
# 22  2017-10 56994      13.05         16295.1              33
# 23  2017-11 59354      13.12         16489.5              32
# 24  2017-12 66661      13.52         16596.4              32
# 25  2018-01 44363      14.14         16740.7              33
# 26  2018-02 43713      14.68         16852.5              35
# 27  2018-03 50701      14.79         17070.3              34
# 28  2018-04 47534      14.83         17354.3              32
# 29  2018-05 55502      13.88         17499.7              34
# 30  2018-06 57064      13.10         17722.0              32
# ... ...     ...        ...           ...                  ...
# 43  2019-07 38931      21.06         20677.1               35
# 44  2019-08 40634      14.15         21199.4               45
# 45  2019-09 51393      12.98         21435.3               40
# 46  2019-10 50181      13.12         21816.8               38
# 47  2019-11 48909      12.96         21914.7               35
# 48  2019-12 75480      12.69         22149.3               36
# 49  2020-01 36040      11.88         22278.1               43
# 50  2020-02 37303      11.43         22530.4               41
# 51  2020-03 34089      11.40         22604.2               33
# 52  2020-04 14848      11.72         22838.6               36
# 53  2020-05 16860      11.23         23332.7               59
# 54  2020-06 58632       9.30         23348.3              100
# 55  2020-07 67937       9.11         23450.1               74
# 56  2020-08 52123      11.09         23589.1               71
# 57  2020-09 41376      14.16         23934.8               52
# 58  2020-10 36976      15.07         24521.4               48
# 59  2020-11 36658      15.68         24997.1               43
# 60  2020-12 36898      18.19         25337.7               40
# 61  2021-01 22268      18.39         25632.0               46
# 62  2021-02 24737      17.99         26012.0               44
# 63  2021-03 33365      17.74         26305.1               42
# 64  2021-04 29212      18.13         26570.7               41
# 65  2021-05 18204      17.84         27015.4               48
# 66  2021-06 40092      17.90         27113.1               48
# 67  2021-07 32672      17.93         27525.9               49
# 68  2021-08 42639      17.86         28044.3               49
# 69  2021-09 43967      17.90         28667.7               44
# 70  2021-10 41914      17.82         29611.7               43
# 71  2021-11 55706      17.10         31007.8               44
# 72  2021-12 76747      17.31         33998.8               46
#     month_of_date year_of_date
# 1   1             1
# 2   2             2
# 3   3             3
# 4   4             4
# 5   5             5
# 6   6             6
# 7   7             7
# 8   8             8
# 9   9             9
# 10  10            10
# 11  11            11
# 12  12            12
# 13  1             1
# 14  2             2
# 15  3             3
# 16  4             4
# 17  5             5
# 18  6             6
# 19  7             7
# 20  8             8
# 21  9             9
# 22  10            10
# 23  11            11
# 24  12            12
# 25  1             1
# 26  2             2
# 27  3             3
# 28  4             4
# 29  5             5
# 30  6             6
# ... ...           ...
# 43  7             7
# 44  8             8
# 45  9             9
# 46  10            10
# 47  11            11
# 48  12            12
# 49  1             1
# 50  2             2
# 51  3             3
# 52  4             4
# 53  5             5
# 54  6             6
# 55  7             7
# 56  8             8
# 57  9             9
# 58  10            10
# 59  11            11
# 60  12            12
# 61  1             1
# 62  2             2
# 63  3             3
# 64  4             4
# 65  5             5
# 66  6             6
# 67  7             7
# 68  8             8
# 69  9             9
# 70  10            10
# 71  11            11
# 72  12            12

# %%
corrplot(cor(data_table_summary[,c(2:7)]),method="number",title = "Corrplot of different variables",mar=c(0,0,1,0))
# Out:
# Plot with title "Corrplot of different variables"
